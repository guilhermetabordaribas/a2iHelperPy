# %%
import os
import time
# import itertools

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# # from adjustText import adjust_text
# from statannotations.Annotator import Annotator

# # import warnings
# from scipy.stats import chi2_contingency, fisher_exact, f_oneway, tukey_hsd, kruskal

# %%
sns.set_style("whitegrid")

# %%
import sys
import importlib
sys.path.append('/mnt/d/GoTx_Folder/src')
# from a2ihelper import call_reditools,
# import a2ihelper
# importlib.reload(a2i)
import a2ihelper as a2i

# %% [markdown]
# # a2iHelper demonstration

# %% [markdown]
# ## Get expression data from public study GSE145011

# %%
df_genes_demo = pd.read_excel('/mnt/e/editing_methods/PRJNA605715_GSE145011/mmc3.xlsx', sheet_name='Table S3b', header=1)
df_genes_demo_en = pd.read_excel('/mnt/e/editing_methods/PRJNA605715_GSE145011/mmc3.xlsx', sheet_name='Table S3a', header=1)
df_genes_demo_en_2 = pd.read_csv('/mnt/e/editing_methods/PRJNA605715_GSE145011/mmc4.txt', sep=' ')

df_genes_demo['count'] = df_genes_demo.gene.map(dict(dict(df_genes_demo_en.groupby('Gene').count().Region)))
df_genes_demo['count2'] = df_genes_demo.gene.map(dict(df_genes_demo_en_2.groupby('SYMBOL').count().sort_values('R_P', ascending=False).R_P))
df_genes_demo['count3'] = df_genes_demo['count'].fillna(df_genes_demo['count2'])
df_genes_demo['count3'] = df_genes_demo['count3'].fillna(df_genes_demo['count'])
df_genes_demo['-log10(fdr)'] = -np.log10(df_genes_demo['p.adj'])
# Out:
# /tmp/ipykernel_270336/3172618387.py:3: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_genes_demo_en_2 = pd.read_csv('/mnt/e/editing_methods/PRJNA605715_GSE145011/mmc4.txt', sep=' ')

# %%
df_genes_demo.head()
# Out:
#       gene    .y. group1 group2             p         p.adj p.format p.signif  \
# 0  FAM129C  value   Ctrl  Cases  1.690000e+00  3.400000e-13  1.7e-14     ****
# 1    CCAR1  value   Ctrl  Cases  4.540000e+05  2.500000e-07  4.5e-08     ****
# 2    IKZF3  value   Ctrl  Cases  1.020000e+06  6.300000e-08  1.0e-08     ****
# 3   NPLOC4  value   Ctrl  Cases  2.220000e-03  9.900000e-16  < 2e-16     ****
# 4     MDM4  value   Ctrl  Cases  1.810000e+03  1.900000e-10  1.8e-11     ****
#
#      method  count  count2  count3  -log10(fdr)
# 0  Wilcoxon    NaN     NaN     NaN    12.468521
# 1  Wilcoxon    NaN     7.0     7.0     6.602060
# 2  Wilcoxon   34.0    16.0    34.0     7.200659
# 3  Wilcoxon    NaN     4.0     4.0    15.004365
# 4  Wilcoxon   38.0     2.0    38.0     9.721246

# %% [markdown]
# ## Get the 100th most relevant genes in the public dataset as an example and the annotation to get coordinates

# %%
gene_list = df_genes_demo.sort_values(['count2','-log10(fdr)'], ascending=False).head(100).gene.tolist()+['ADAR','UBR4','WDR12','APOL1']
path_ref_annotation='/mnt/e/editing_methods/PRJNA605715_GSE145011/gencode.v44.basic.annotation.gtf'

# %%
len(gene_list)
# Out:
# 104

# %% [markdown]
# ## Get coordinates with get_genes_positions function

# %%
t1 = time.time()
gene_coord = a2i.call_reditools2.get_genes_positions(gene_list, path_ref_annotation, gzip_file=False)
t2 = time.time()
print(int((t2-t1)//60), (t2-t1)%60, sep=':')
# Out:
# 0:18.747475624084473

# %%
print(dict(list(gene_coord.items())[:2]), '...', dict(list(gene_coord.items())[-2:]))
# Out:
# {'MRPL20': 'chr1:1401909-1407293', 'ATAD3B': 'chr1:1471765-1497848'} ... {'GNL3L': 'chrX:54530183-54621521', 'MAGT1': 'chrX:77825747-77899271'}

# %% [markdown]
# ## Call reditools2

# %% [markdown]
# ### Call samtools index
# Before calling reditools2, having the index file for each bam file is mandatory. It can be done with the bash script below.

# %%
# %bash
# #!/bin/bash

# pathIn="/mnt/d/rna_editing/" #path with the bams files

# arr=(${pathIn}*ready.bam)
# for filename in ${arr[@]##*/}; do
#     echo ${filename}
#     time samtools index ${pathIn}${filename}
# done
# echo "BAI files DONE!"

# %% [markdown]
# ### Preparing the arguments for the run_per_gene_position_list function

# %%
genes_positions = gene_coord.values()
in_bam_file_list = ['/mnt/e/editing_methods/PRJNA605715_GSE145011/star_1pass/'+f for f in os.listdir('/mnt/e/editing_methods/PRJNA605715_GSE145011/star_1pass/') if f.endswith('bam')]
path_out_res = '/mnt/e/editing_methods/PRJNA605715_GSE145011/RES/'
ref_genome_file = '/mnt/e/reference_files/GRCh38.p14.genome.fa'
path_reditools = '/mnt/d/reditools2.0/src/cineca/'
reditools_options = ''
# reditools_options = '--strict' use strict in case only editing sites are in the output
n_jobs = 10

# %%
# t1 = time.time()
# for in_bam_file in in_bam_file_list:
#     a2i.call_reditools2.run_per_gene_position_list(genes_positions, in_bam_file, path_out_res, ref_genome_file, path_reditools, reditools_options=reditools_options, n_jobs=n_jobs)
#     print('#',end=' ')
# t2 = time.time()
# print(int((t2-t1)//60), (t2-t1)%60, sep=':')

# %% [markdown]
# ### Preparing the metadata files to integrate

# %%
import gzip

t1 = time.time()
meta_names = ['!Sample_title','!Sample_geo_accession', '!Sample_source_name_ch1', '!Sample_source_name_ch2','!Sample_characteristics_ch1']
gse_meta = open('/mnt/e/editing_methods/PRJNA605715_GSE145011/'+'PRJNA605715_GSE145011_meta.tsv', 'w')

with gzip.open('/mnt/e/editing_methods/PRJNA605715_GSE145011/'+'GSE145011_series_matrix.txt.gz') as gse:
    expr_flag = False
    for line in gse:
        if line.decode().split('\t')[0] in meta_names:            
            gse_meta.write(line.decode())
gse_meta.close()
t2 = time.time()
print(int((t2-t1)//60), (t2-t1)%60, sep=':')
# Out:
# 0:2.6092746257781982

# %%
meta_1 = pd.read_csv('/mnt/e/editing_methods/PRJNA605715_GSE145011/PRJNA605715_GSE145011_meta.tsv', sep='\t', index_col=0).T.reset_index()#.set_index('!Sample_geo_accession')
meta_1[['cell_line','condition']] = meta_1['index'].str.split('_', expand=True)
# meta_1 = meta_1.drop(['index'], axis=1)
meta_1.columns = ['cell_line_condition','geo_acc','1','genotype','tissue','4','cell_line', 'condition']
meta_1 = meta_1.drop(['1', '4'], axis=1)
meta_1['genotype'] = meta_1['genotype'].str.replace('genotype: ','')
meta_1['tissue'] = meta_1['tissue'].str.replace('tissue: ','')

meta_2 = pd.read_csv('/mnt/e/editing_methods/PRJNA605715_GSE145011/SraRunTable.txt')[['Run','Sample Name']]
meta_2.columns = ['Run','geo_acc']

meta_1 = meta_1.merge(meta_2, on='geo_acc')

# %%
meta_1
# Out:
#    cell_line_condition     geo_acc   genotype           tissue cell_line  \
# 0             A549_WT1  GSM4304246  wild type   Lung carcinoma      A549
# 1             A549_WT2  GSM4304247  wild type   Lung carcinoma      A549
# 2             A549_WT3  GSM4304248  wild type   Lung carcinoma      A549
# 3             A549_KO1  GSM4304249   ADAR1-/-   Lung carcinoma      A549
# 4             A549_KO2  GSM4304250   ADAR1-/-   Lung carcinoma      A549
# 5             A549_KO3  GSM4304251   ADAR1-/-   Lung carcinoma      A549
# 6            RC-K8_WT1  GSM4304252  wild type  B-cell lymphoma     RC-K8
# 7            RC-K8_WT2  GSM4304253  wild type  B-cell lymphoma     RC-K8
# 8            RC-K8_WT3  GSM4304254  wild type  B-cell lymphoma     RC-K8
# 9            RC-K8_KO1  GSM4304255   ADAR1-/-  B-cell lymphoma     RC-K8
# 10           RC-K8_KO2  GSM4304256   ADAR1-/-  B-cell lymphoma     RC-K8
# 11           RC-K8_KO3  GSM4304257   ADAR1-/-  B-cell lymphoma     RC-K8
#
#    condition          Run
# 0        WT1  SRR11050913
# 1        WT2  SRR11050914
# 2        WT3  SRR11050915
# 3        KO1  SRR11050916
# 4        KO2  SRR11050917
# 5        KO3  SRR11050918
# 6        WT1  SRR11050919
# 7        WT2  SRR11050920
# 8        WT3  SRR11050921
# 9        KO1  SRR11050922
# 10       KO2  SRR11050923
# 11       KO3  SRR11050924

# %% [markdown]
# ### Integrating the file name, coordinates, and SRA code to the metadata.
# The metadata must contain the follow information in the same order:
#
# - First column: Full path file names of REDItools2 results tables
# - Second column: Samples names
# - Third column: region (gene symbol)
# - Fourth column: conditions

# %%
meta = pd.DataFrame(os.listdir(path_out_res))
meta.columns = ['file_name']
meta[['Run','coord']] = meta.file_name.str.split('_Aligned.sortedByCoord.out.bam_', n=1, expand=True)
meta['coord'] = meta.coord.str.replace('_RES.tsv','')
meta['coord'] = meta.coord.str.replace('_',':', n=1)
meta['coord'] = meta.coord.str.replace('_','-')
meta['region'] = meta['coord'].map({value:key for key,value in gene_coord.items()})
meta['file_name'] = path_out_res+meta.file_name

meta = meta.merge(meta_1, on='Run')

meta = meta[['file_name', 'Run', 'region', 'genotype', 'cell_line_condition', 'condition','cell_line',  'coord']]
meta
# Out:
#                                               file_name          Run  \
# 0     /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050913
# 1     /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050913
# 2     /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050913
# 3     /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050913
# 4     /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050913
# ...                                                 ...          ...
# 1243  /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050924
# 1244  /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050924
# 1245  /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050924
# 1246  /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050924
# 1247  /mnt/e/editing_methods/PRJNA605715_GSE145011/R...  SRR11050924
#
#         region   genotype cell_line_condition condition cell_line  \
# 0        WDFY4  wild type            A549_WT1       WT1      A549
# 1     C11orf58  wild type            A549_WT1       WT1      A549
# 2        EP400  wild type            A549_WT1       WT1      A549
# 3         POLE  wild type            A549_WT1       WT1      A549
# 4       GOLGA3  wild type            A549_WT1       WT1      A549
# ...        ...        ...                 ...       ...       ...
# 1243     SYAP1   ADAR1-/-           RC-K8_KO3       KO3     RC-K8
# 1244    SLC9A7   ADAR1-/-           RC-K8_KO3       KO3     RC-K8
# 1245      RBM3   ADAR1-/-           RC-K8_KO3       KO3     RC-K8
# 1246     GNL3L   ADAR1-/-           RC-K8_KO3       KO3     RC-K8
# 1247     MAGT1   ADAR1-/-           RC-K8_KO3       KO3     RC-K8
#
#                           coord
# 0       chr10:48684873-48982956
# 1       chr11:16613132-16758340
# 2     chr12:131949942-132080460
# 3     chr12:132623753-132687376
# 4     chr12:132768902-132829143
# ...                         ...
# 1243     chrX:16719612-16765340
# 1244     chrX:46599251-46759118
# 1245     chrX:48574449-48581162
# 1246     chrX:54530183-54621521
# 1247     chrX:77825747-77899271
#
# [1248 rows x 8 columns]

# %% [markdown]
# ### Merging all editing files to perform analysis

# %%
time1 = time.time()
df, df_a, df_g, region_list = a2i.editing.merge_files_all_regions(meta)#[meta.cell_line=='RC-K8'])
time2 = time.time() - time1
print(int((t2-t1)//60), (t2-t1)%60, sep=':')
# Out:
# 0:2.6092746257781982

# %% [markdown]
# ### Applying filter by nan values, zeros and 100% of editing.

# %%
df = a2i.editing.filter_positions(df, nan_filter=True, nan_filter_limit=4, zero_filter=False, hundred_filter=False,  per_condition=False)

# %%
df
# Out:
#              11_16744616  11_16744620  11_16744631  11_16744632  11_16744675  \
# SRR11050913     0.142399     0.037147     0.032841     0.064267     0.379507
# SRR11050914     0.175850     0.030950     0.027902     0.054585     0.207523
# SRR11050915     0.033311     0.104493     0.062696     0.030960     0.352338
# SRR11050916     0.058309          NaN     0.053576     0.052673     0.425000
# SRR11050917     0.087642          NaN     0.025974          NaN     0.405922
# SRR11050918     0.061920     0.032175     0.028114          NaN     0.501379
# SRR11050919     0.127470     0.048457     0.104337     0.058858     0.284136
# SRR11050920     0.085161     0.022134     0.102145     0.060289     0.193966
# SRR11050921     0.045086     0.069573     0.064921     0.042735     0.046555
# SRR11050922     0.053807     0.111235          NaN     0.078616     0.320793
# SRR11050923     0.077963     0.026532          NaN     0.074276     0.160944
# SRR11050924     0.133049          NaN     0.102775     0.074720     0.078802
#
#              11_16748108  11_16748111  11_16748122  11_16748149  11_16752815  \
# SRR11050913     0.237741     0.157580     0.056867     0.080150     0.105152
# SRR11050914     0.240038     0.228542          NaN          NaN     0.138281
# SRR11050915     0.271493     0.324254     0.029011          NaN     0.028090
# SRR11050916     0.140056     0.098256          NaN          NaN     0.171380
# SRR11050917     0.313269     0.256949     0.041580     0.020149     0.121065
# SRR11050918     0.162262     0.247341     0.066372     0.021286     0.170648
# SRR11050919     0.154655     0.016611     0.030148     0.014529     0.107444
# SRR11050920     0.041434     0.088909     0.039308     0.037230     0.128488
# SRR11050921     0.133067     0.023557     0.043169     0.020231     0.121729
# SRR11050922     0.084986     0.149076     0.080150     0.025132     0.073892
# SRR11050923     0.106270     0.028233     0.128337     0.023132     0.046653
# SRR11050924     0.101240          NaN          NaN          NaN     0.023143
#
#              ...  X_77828545  X_77828723  X_77828981  X_77856805  X_77857415  \
# SRR11050913  ...    0.767263    0.815661    0.534759    0.760456    0.168067
# SRR11050914  ...    1.250000         NaN    0.628931    1.890034    0.270636
# SRR11050915  ...    0.210970         NaN    0.465116    1.214575    0.949367
# SRR11050916  ...         NaN    0.548246    0.208333    1.144492    0.352526
# SRR11050917  ...         NaN    0.232019    1.399491    0.274348    0.722892
# SRR11050918  ...         NaN    0.623053    0.923788    0.928382    0.814901
# SRR11050919  ...   11.111111    0.796813    1.388889         NaN         NaN
# SRR11050920  ...   12.857143    0.440529    2.083333         NaN    0.446429
# SRR11050921  ...   13.106796    0.450450         NaN         NaN    0.257069
# SRR11050922  ...    0.403226         NaN         NaN    0.526316         NaN
# SRR11050923  ...    0.476190    1.463415    2.000000         NaN    0.327869
# SRR11050924  ...         NaN         NaN         NaN    2.500000         NaN
#
#              X_77875460  X_77826960  X_77828141   region   genotype
# SRR11050913    0.564972         NaN         NaN  several  wild type
# SRR11050914    0.486027    0.414938    0.896057  several  wild type
# SRR11050915    0.154321    0.599700    0.218341  several  wild type
# SRR11050916    0.110254    0.527426    0.320000  several   ADAR1-/-
# SRR11050917    0.225225    0.092678    0.339559  several   ADAR1-/-
# SRR11050918    0.222717    0.214133    0.182815  several   ADAR1-/-
# SRR11050919    0.166667    0.492611         NaN  several  wild type
# SRR11050920    0.202429         NaN    0.400000  several  wild type
# SRR11050921         NaN    1.315789         NaN  several  wild type
# SRR11050922         NaN    0.401606         NaN  several   ADAR1-/-
# SRR11050923         NaN    0.843882    0.390625  several   ADAR1-/-
# SRR11050924         NaN    1.123596    0.373134  several   ADAR1-/-
#
# [12 rows x 3779 columns]

# %% [markdown]
# ## Statistics for frequency data

# %% [markdown]
# ### Anova tukey
# The funtion anova_tukey_test returns the p-values for ANOVA test.

# %%
df_pv = a2i.stats.anova_tukey_test(df, only_pvalue=True, pvalue_filter_limit_anova=.05, pvalue_filter_limit_tukey=.05, return_only_significant=True)
df_pv
# Out:
# /mnt/d/GoTx_Folder/src/a2ihelper/stats.py:141: ConstantInputWarning: Each of the input arrays is constant; the F statistic is not defined or infinite
#   aux_aov = f_oneway(*data_by_condition)
# coord                 12_98599984 17_80353632 19_41861150 19_41861168  \
# tests
# (wild type, ADAR1-/-)    0.021365    0.024347    0.040579    0.032321
#
# coord                 19_55386433 19_55386578 19_55388245 20_3867545  \
# tests
# (wild type, ADAR1-/-)    0.017189    0.032522     0.03586   0.000112
#
# coord                 2_206144963 3_45680382 5_172952431 7_44799741  \
# tests
# (wild type, ADAR1-/-)    0.047728   0.000163    0.016865   0.008789
#
# coord                 7_44801375 7_44801505 X_48576551 X_48577089 X_48577987  \
# tests
# (wild type, ADAR1-/-)   0.006234   0.031004   0.013169   0.028196     0.0017
#
# coord                 X_77827544 X_77828394
# tests
# (wild type, ADAR1-/-)   0.000117   0.004126

# %% [markdown]
# ### Mann-Whitney U rank test

# %%
mw = a2i.stats.mannwhitney_test(df, only_pvalue=True, pvalue_filter_limit_wilcox=.05, return_only_significant=True)
mw
# Out:
# coord  11_16755004 12_98599984 17_80353632 19_41860809 19_41861150  \
# pvalue    0.025974    0.008658    0.008658    0.025974    0.041126
#
# coord  19_41861168 19_41861208 19_41869090 19_55386433 19_55388283  ...  \
# pvalue    0.041126    0.041126    0.025974    0.025974    0.004329  ...
#
# coord  7_44799741 7_44799807 7_44801375 X_48576551 X_48577089 X_48577987  \
# pvalue   0.015152   0.041126   0.015152   0.015152   0.025974   0.002165
#
# coord  X_77827544 X_77828394   region               genotype
# pvalue   0.002165   0.002165  several  wild type_vs_ADAR1-/-
#
# [1 rows x 23 columns]

# %%
ax = a2i.plot.boxplot(df, log_scale=True, pvalue_list=mw.values[0].tolist()[:-2], positions_to_plot=mw.columns.tolist()[:-2])
ax.set_title('Mann-Whitney U rank test')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2B_MW.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Statistics for porprotions

# %% [markdown]
# ### Pooling smaples/coordinates by G-test

# %%
a, g = a2i.editing.pool_positions(df_a[df.columns],df_g[df.columns])

# %%
a
# Out:
#            11_16744616  11_16748108  11_16752815  11_16752839  11_16752876  \
# genotype
# ADAR1-/-       21389.0      24274.0      26952.0      27495.0      23534.0
# wild type      24607.0      26603.0      28564.0      29364.0      25691.0
#
#            11_16755004  12_132769626  12_64421327  12_64439300  12_98597857  \
# genotype
# ADAR1-/-       23572.0           2.0       5647.0       4676.0      49063.0
# wild type      25934.0           2.0       4443.0       4392.0      44439.0
#
#            ...  X_48576328  X_48576551  X_48576569  X_48577089  X_48577487  \
# genotype   ...
# ADAR1-/-   ...     31007.0     33980.0     37368.0     33850.0     25259.0
# wild type  ...     28891.0     29916.0     32864.0     27261.0     17372.0
#
#            X_48577626  X_48577946  X_48578090   region   genotype
# genotype
# ADAR1-/-      13276.0     26526.0     29461.0  several   ADAR1-/-
# wild type      5198.0     23686.0     24636.0  several  wild type
#
# [2 rows x 238 columns]

# %%
g
# Out:
#            11_16744616  11_16748108  11_16752815  11_16752839  11_16752876  \
# genotype
# ADAR1-/-          17.0         38.0         28.0         49.0         16.0
# wild type         25.0         45.0         31.0         39.0         22.0
#
#            11_16755004  12_132769626  12_64421327  12_64439300  12_98597857  \
# genotype
# ADAR1-/-          30.0        1166.0         48.0         20.0         51.0
# wild type         16.0        1200.0         42.0         29.0         37.0
#
#            ...  X_48576328  X_48576551  X_48576569  X_48577089  X_48577487  \
# genotype   ...
# ADAR1-/-   ...        20.0        47.0        86.0        43.0        33.0
# wild type  ...        35.0        12.0        79.0        54.0        37.0
#
#            X_48577626  X_48577946  X_48578090   region   genotype
# genotype
# ADAR1-/-         37.0        21.0       170.0  several   ADAR1-/-
# wild type        23.0        16.0       115.0  several  wild type
#
# [2 rows x 238 columns]

# %%
chi = a2i.stats.chi2_test(a,g,only_pvalue=True,pvalue_filter_limit=.05)
chi
# Out:
#         11_16755004  12_98599984  15_44561843  19_41860835  19_41860843  \
# pvalue     0.024408     0.004265     0.037467     0.037716     0.048953
#
#         19_41861150  19_41869033  19_41869717  19_55386571  19_55386578  ...  \
# pvalue     0.030356     0.008368     0.041716      0.04406     0.030622  ...
#
#         5_172952431  7_44799741  7_44799807  7_44801292  7_44801505  \
# pvalue     0.019568    0.013371    0.006147    0.025404    0.031881
#
#         X_48576328  X_48576551  X_48577089   region               genotype
# pvalue    0.030934    0.000043    0.037573  several  ADAR1-/-_vs_wild type
#
# [1 rows x 26 columns]

# %%
ax = a2i.plot.boxplot(df, log_scale=False, pvalue_list=chi.values[0].tolist()[:-2], positions_to_plot=chi.columns.tolist()[:-2])
ax.set_title('Chi square test')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2A_chi2.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %%
fis = a2i.stats.fisher_test(a,g,only_pvalue=True,pvalue_filter_limit=1)
fis
# Out:
#         11_16744616  11_16748108  11_16752815  11_16752839  11_16752876  \
# pvalue     0.444844     0.742769     0.896941     0.199999     0.519128
#
#         11_16755004  12_132769626  12_64421327  12_64439300  12_98597857  ...  \
# pvalue     0.018106           1.0     0.670001     0.152222     0.337001  ...
#
#         X_48576328  X_48576551  X_48576569  X_48577089  X_48577487  \
# pvalue    0.029863    0.000035    0.814907    0.031661    0.050668
#
#         X_48577626  X_48577946  X_48578090   region               genotype
# pvalue    0.085161    0.742406    0.083754  several  ADAR1-/-_vs_wild type
#
# [1 rows x 238 columns]

# %%
or_ = a2i.editing.odds_r(a.loc[:,fis.columns], g.loc[:,fis.columns])
or_
# Out:
#             11_16744616  11_16748108  11_16752815  11_16752839  11_16752876  \
# odds_ratio     1.278264     1.080535     1.044661     0.745263      1.25955
#
#             11_16755004  12_132769626  12_64421327  12_64439300  12_98597857  \
# odds_ratio     0.484766      1.029147     1.112103     1.543688     0.800981
#
#             ...  X_48576328  X_48576551  X_48576569  X_48577089  X_48577487  \
# odds_ratio  ...    1.878152    0.290008    1.044498    1.559334    1.630231
#
#             X_48577626  X_48577946  X_48578090   region               genotype
# odds_ratio    1.587615    0.853261    0.808962  several  ADAR1-/-_vs_wild type
#
# [1 rows x 238 columns]

# %%
ax = a2i.plot.manhattanplot(or_, fis, p_value_line=0.05, chr_order=['1', '2', '3', '5', '7', '9', '11', '12','15', '16', '17', '19', 'X'])
ax.set_title('Manhattan Plot')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2C_manhattanplot.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Entropy calcluation

# %%
entr = a2i.stats.entropy_calculation(a,g)
entr
# Out:
#            11_16744616  11_16748108  11_16752815  11_16752839  11_16752876  \
# ADAR1-/-      0.006463     0.011661     0.008168     0.013041     0.005635
# wild type     0.008010     0.012467     0.008485     0.010113     0.006899
#
#            11_16755004  12_132769626  12_64421327  12_64439300  12_98597857  \
# ADAR1-/-      0.009746      0.012618     0.048648     0.027498     0.008172
# wild type     0.005174      0.012309     0.053061     0.039512     0.006731
#
#            ...  X_48575266  X_48575279  X_48576328  X_48576551  X_48576569  \
# ADAR1-/-   ...    0.002930    0.009293    0.005380    0.010476    0.016246
# wild type  ...    0.004042    0.009190    0.009337    0.003537    0.016863
#
#            X_48577089  X_48577487  X_48577626  X_48577946  X_48578090
# ADAR1-/-     0.009730    0.009970    0.019133    0.006441    0.035329
# wild type    0.014284    0.015202    0.028294    0.005603    0.029594
#
# [2 rows x 236 columns]

# %%
# # This is just to correct the order of the coordinates
# aux = pd.DataFrame([i.split('_') for i in entr.columns])
# aux_n = aux[aux[0]!='X']
# aux_x = aux[aux[0]=='X']

# aux_n.loc[:,0] = aux_n[0].astype(int)
# aux_n.loc[:,1] = aux_n[1].astype(int)
# aux_n = aux_n.sort_values([0,1])
# aux_n.loc[:,0] = aux_n[0].astype(str)
# aux_n.loc[:,1] = aux_n[1].astype(str)

# aux_x.loc[:,1] = aux_x[1].astype(int)
# aux_x = aux_x.sort_values(1)
# aux_x.loc[:,1] = aux_x[1].astype(str)

# aux = pd.concat([aux_n, aux_x])
# aux[2] = aux[0] + '_' + aux[1]

# %%
ax = a2i.plot.entropy_plot(entr, n_top=30)
ax.set_title('Entropy Plot')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2D_entropy.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### Pearson correlation tests

# %%
pearson = a2i.stats.conditon_pearson_corr(df[chi.columns].fillna(0), return_only_significant=False ,pvalue_filter_limit=0.05)
pearson
# Out:
#       Positions         R    pvalue
# 0   11_16755004 -0.177720  0.736226
# 1   12_98599984  0.329284  0.523926
# 2   15_44561843  0.400999  0.430741
# 3   19_41860835 -0.447937  0.373033
# 4   19_41860843 -0.107692  0.839086
# 5   19_41861150 -0.244182  0.641007
# 6   19_41869033  0.335755  0.515292
# 7   19_41869717  0.377648  0.460457
# 8   19_55386571  0.278501  0.593050
# 9   19_55386578 -0.335177  0.516061
# 10  19_55386665  0.027273  0.959100
# 11  19_55388002 -0.862041  0.027236
# 12  19_55388245  0.214028  0.683860
# 13  19_55388283 -0.035748  0.946400
# 14  19_55388304  0.469988  0.346926
# 15  5_172924006  0.524550  0.285341
# 16  5_172952431 -0.027900  0.958161
# 17   7_44799741 -0.168602  0.749494
# 18   7_44799807 -0.468547  0.348611
# 19   7_44801292 -0.054489  0.918348
# 20   7_44801505  0.339847  0.509855
# 21   X_48576328 -0.298169  0.566001
# 22   X_48576551  0.812046  0.049670
# 23   X_48577089  0.187324  0.722300

# %%
ax = a2i.plot.corr_pearson_plot(pearson, log_scale=True, p_value_line=0.05)
ax.set_title('Pearson correlation of editing sites\nbetween conditions')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2E_corr.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %%
path = '/mnt/e/editing_methods/PRJNA605715_GSE145011/trimmed_salmon_quant/'
tpm_aux = []
for srr in os.listdir(path):
    tpm_aux.append(pd.read_csv(path+srr+'/quant.sf', sep='\t')[['Name','TPM']])
    tpm_aux[-1]['Run'] = srr
tpm = pd.concat(tpm_aux)

# %%
exprs = tpm[tpm.Name.str.contains('ENST00000368474')]
exprs.TPM.values
# Out:
# array([ 3.252617,  4.299662,  4.713678,  0.      ,  0.      ,  0.      ,
#        39.336771, 41.647236, 25.591093, 16.625418, 20.444033, 20.640526])

# %%
g_pearson = a2i.stats.gene_pearson_corr(df[chi.columns].fillna(0), exprs.TPM.values,return_only_significant=False)
g_pearson
# Out:
#       Positions         R    pvalue
# 0   11_16755004 -0.691477  0.012744
# 1   12_98599984  0.028309  0.930407
# 2   15_44561843 -0.707110  0.010119
# 3   19_41860835 -0.035925  0.911742
# 4   19_41860843 -0.654160  0.021012
# 5   19_41861150 -0.067442  0.835032
# 6   19_41869033  0.129127  0.689186
# 7   19_41869717 -0.698366  0.011532
# 8   19_55386571 -0.553267  0.062043
# 9   19_55386578  0.162087  0.614760
# 10  19_55386665  0.005451  0.986586
# 11  19_55388002 -0.057689  0.858659
# 12  19_55388245  0.073916  0.819415
# 13  19_55388283 -0.069710  0.829556
# 14  19_55388304  0.171629  0.593787
# 15  5_172924006 -0.760624  0.004074
# 16  5_172952431 -0.087673  0.786439
# 17   7_44799741 -0.243549  0.445584
# 18   7_44799807 -0.217543  0.497015
# 19   7_44801292 -0.016010  0.960615
# 20   7_44801505 -0.284188  0.370674
# 21   X_48576328  0.021110  0.948080
# 22   X_48576551 -0.659710  0.019586
# 23   X_48577089  0.357053  0.254553

# %%
ax = a2i.plot.corr_pearson_plot(g_pearson, log_scale=True, p_value_line=0.05)
ax.set_title('Pearson correlation between\nADAR expression and editing frequencies')
plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2F_adar_corr.pdf', format='pdf', dpi=300,bbox_inches='tight')

# %% [markdown]
# # Fig_2

# %%
fig = plt.figure(figsize=(8.35*2,8.35))

ax_chi = fig.add_subplot(231)
a2i.plot.boxplot(df, log_scale=False, pvalue_list=chi.values[0].tolist()[:-2], positions_to_plot=chi.columns.tolist()[:-2], ax=ax_chi)
ax_chi.set_title('Chi square test')

ax_mw = fig.add_subplot(232)
a2i.plot.boxplot(df, log_scale=True, pvalue_list=mw.values[0].tolist()[:-2], positions_to_plot=mw.columns.tolist()[:-2], ax=ax_mw)
ax_mw.set_title('Mann-Whitney U rank test')

ax_mh = fig.add_subplot(233)
a2i.plot.manhattanplot(or_, fis, p_value_line=0.05, chr_order=['1', '2', '3', '5', '7', '9', '11', '12','15', '16', '17', '19', 'X'], ax=ax_mh)
ax_mh.set_title('Manhattan Plot')

ax_entr = fig.add_subplot(234)
a2i.plot.entropy_plot(entr, n_top=30, ax=ax_entr)
ax_entr.set_title('Entropy Plot')

ax_ep = fig.add_subplot(234)
a2i.plot.corr_pearson_plot(pearson, log_scale=True, p_value_line=0.05, ax=ax_ep)
ax_ep.set_title('Pearson correlation of editing sites\nbetween conditions')

# plt.savefig('/mnt/d/GoTx_Folder/draft/FIG2A_chi2.pdf', format='pdf', dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Entropy Plot')
